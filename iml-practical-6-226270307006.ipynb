# %% [markdown]
# **Write a Pandas program to implement following operation**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **1) To convert a NumPy array to a Pandas series**

# %%
a=np.array([24,12,20,10])
print("Array :",a)

x=pd.Series(a)
print("Series :\n",x)
# Out:
# Array : [24 12 20 10]
#  Series :
#  0    24
# 1    12
# 2    20
# 3    10
# dtype: int64

# %% [markdown]
# **2) To convert the first column of a DataFrame as a Series**

# %%
dict ={
    "Name": ['Jiya','Riya'],
    "City": ['Porbandar', 'Porbandar']
              
}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#    Name       City
# 0  Jiya  Porbandar
# 1  Riya  Porbandar

# %%
s= pd.Series(df['Name'])

# %%
s
# Out:
# 0    Jiya
# 1    Riya
# Name: Name, dtype: object

# %% [markdown]
# **3) To create the mean and standard deviation of the data of a given
# Series**

# %%
x
# Out:
# 0    24
# 1    12
# 2    20
# 3    10
# dtype: int64

# %%
print("Means :",x.mean())
print("Varience :",x.std())
# Out:
# Means : 16.5
# Varience : 6.60807586719967

# %% [markdown]
# **4) To sort a given Series**

# %%
print("Series Before Sorting :\n",x)

s1=x.sort_values()
print("Series After Sorting :\n",s1)
# Out:
# Series Before Sorting :
#  0    24
# 1    12
# 2    20
# 3    10
# dtype: int64
# Series After Sorting :
#  3    10
# 1    12
# 2    20
# 0    24
# dtype: int64

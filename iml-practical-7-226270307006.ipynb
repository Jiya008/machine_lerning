# %% [markdown]
# **Write a Pandas program to implement following operation**

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **1) To create a dataframe from a dictionary and display it**

# %%
dict={
    "name" : ['Jiya','Riya','Himani','Viddhi','Diya'],
    "Age" : [18,18,19,19,19],
    "Department" : ['Computer','Computer','Computer','Computer','Computer']
}

# %%
d = pd.DataFrame(dict)

# %%
d
# Out:
#      name  Age Department
# 0    Jiya   18   Computer
# 1    Riya   18   Computer
# 2  Himani   19   Computer
# 3  Viddhi   19   Computer
# 4    Diya   19   Computer

# %% [markdown]
# **2) To sort the DataFrame first by 'name' in ascending order**

# %%
df_new= d.sort_values(by = ['name'])

# %%
df_new
# Out:
#      name  Age Department
# 4    Diya   19   Computer
# 2  Himani   19   Computer
# 0    Jiya   18   Computer
# 1    Riya   18   Computer
# 3  Viddhi   19   Computer

# %% [markdown]
# **3) To delete the one specific column from the DataFrame**

# %%
del d['Age']

# %%
d
# Out:
#      name Department
# 0    Jiya   Computer
# 1    Riya   Computer
# 2  Himani   Computer
# 3  Viddhi   Computer
# 4    Diya   Computer

# %% [markdown]
# **4) To write a DataFrame to CSV file using tab separator**

# %%
d.to_csvarrays('/kaggle/working/dataset.csv', index=False, sep="\t")

# %%
df = pd.read_csv('/kaggle/working/dataset.csv')

# %%
df
# Out:
#    name\tDepartment
# 0    Jiya\tComputer
# 1    Riya\tComputer
# 2  Himani\tComputer
# 3  Viddhi\tComputer
# 4    Diya\tComputer
